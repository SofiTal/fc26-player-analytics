# %%
# importation des packages
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\w10az\OneDrive\Projets persos\fc26-player-analytics\.venv\Scripts\python.exe
